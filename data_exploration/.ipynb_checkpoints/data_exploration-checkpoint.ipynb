# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
from scipy import stats
sns.set_style('whitegrid')
sns.set_palette("Set1")

# %% [markdown]
# # Load Dataset

# %%
raw_data = pd.read_csv("./data/loans.csv", sep=",")
pd.set_option('display.max_columns', None)

# %% [markdown]
# # General Data Statistics

# %%
raw_data.shape
# Out:
# (421097, 137)

# %%
raw_data.head(-1)
# Out:
#                                                       id  member_id  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 421091                                               NaN        NaN
# 421092                                               NaN        NaN
# 421093                                               NaN        NaN
# 421094                                               NaN        NaN
# 421095  Total amount funded in policy code 1: 6417608175        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         20000.0      20000.0          20000.0   36 months    6.49%
# 1         10000.0      10000.0          10000.0   36 months   11.48%
# 2         21000.0      21000.0          21000.0   60 months   13.99%
# 3         24000.0      24000.0          24000.0   60 months    9.80%
# 4         14025.0      14025.0          14025.0   60 months   18.49%
# ...           ...          ...              ...         ...      ...
# 421091    10000.0      10000.0          10000.0   36 months   11.99%
# 421092    12000.0      12000.0          12000.0   60 months   19.99%
# 421093    13000.0      13000.0          13000.0   60 months   15.99%
# 421094    20000.0      20000.0          20000.0   36 months   11.99%
# 421095        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade                        emp_title  \
# 0            612.89     A        A2      TEAM LEAD, QUALITY ENGINEER
# 1            329.67     B        B5                        Paralegal
# 2            488.53     C        C4               Resident physician
# 3            507.58     B        B3                              NaN
# 4            359.90     D        D5                    accts payable
# ...             ...   ...       ...                              ...
# 421091       332.10     B        B5                 Office Assistant
# 421092       317.86     E        E3                          Painter
# 421093       316.07     D        D2         Radiologist Technologist
# 421094       664.20     B        B5  Manager Hotel Operations Oasis
# 421095          NaN   NaN       NaN                              NaN
#
#        emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0         6 years       MORTGAGE     55000.0        Not Verified  Dec-2015
# 1         2 years           RENT     33000.0        Not Verified  Dec-2015
# 2        < 1 year           RENT     52000.0     Source Verified  Dec-2015
# 3             NaN            OWN     77900.0        Not Verified  Dec-2015
# 4       10+ years       MORTGAGE     39000.0            Verified  Dec-2015
# ...           ...            ...         ...                 ...       ...
# 421091    8 years           RENT     31000.0            Verified  Jan-2015
# 421092     1 year           RENT     64400.0     Source Verified  Jan-2015
# 421093    5 years           RENT     35000.0            Verified  Jan-2015
# 421094  10+ years           RENT    100000.0            Verified  Jan-2015
# 421095        NaN            NaN         NaN                 NaN       NaN
#
#         loan_status pymnt_plan  url desc             purpose  \
# 0           Current          n  NaN  NaN  debt_consolidation
# 1           Current          n  NaN  NaN  debt_consolidation
# 2           Current          n  NaN  NaN         credit_card
# 3           Current          n  NaN  NaN    home_improvement
# 4        Fully Paid          n  NaN  NaN  debt_consolidation
# ...             ...        ...  ...  ...                 ...
# 421091      Current          n  NaN  NaN  debt_consolidation
# 421092  Charged Off          n  NaN  NaN  debt_consolidation
# 421093  Charged Off          n  NaN  NaN  debt_consolidation
# 421094   Fully Paid          n  NaN  NaN         credit_card
# 421095          NaN        NaN  NaN  NaN                 NaN
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 0            Debt consolidation    381xx         TN  29.15          0.0
# 1            Debt consolidation    477xx         IN  21.75          0.0
# 2       Credit card refinancing    441xx         OH  14.47          0.0
# 3              Home improvement    376xx         TN  10.24          0.0
# 4            Debt consolidation    546xx         WI  18.00          0.0
# ...                         ...      ...        ...    ...          ...
# 421091       Debt consolidation    905xx         CA  28.69          0.0
# 421092       Debt consolidation    010xx         MA  27.19          1.0
# 421093       Debt consolidation    378xx         TN  30.90          0.0
# 421094  Credit card refinancing    331xx         FL  10.83          0.0
# 421095                      NaN      NaN        NaN    NaN          NaN
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0              Sep-1994             0.0                    74.0
# 1              Aug-2009             0.0                     NaN
# 2              Jan-2005             1.0                     NaN
# 3              Oct-1982             1.0                    50.0
# 4              Aug-2001             1.0                     NaN
# ...                 ...             ...                     ...
# 421091         Sep-2004             0.0                     NaN
# 421092         Oct-2003             2.0                    22.0
# 421093         Sep-2003             0.0                     NaN
# 421094         Dec-2001             1.0                     NaN
# 421095              NaN             NaN                     NaN
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  \
# 0                          NaN       9.0      0.0     4851.0      23.8%
# 1                         12.0      12.0      1.0     8052.0      35.6%
# 2                          NaN       5.0      0.0    20374.0      87.4%
# 3                          NaN       9.0      0.0     3454.0      10.3%
# 4                          NaN      12.0      0.0    15646.0      74.9%
# ...                        ...       ...      ...        ...        ...
# 421091                    77.0       9.0      1.0    14037.0      82.1%
# 421092                     NaN      17.0      0.0     8254.0      30.6%
# 421093                    84.0       9.0      1.0    11031.0      61.3%
# 421094                   110.0       8.0      1.0    33266.0      79.8%
# 421095                     NaN       NaN      NaN        NaN        NaN
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0            23.0                   w    9369.66        9369.66  12239.770000
# 1            20.0                   w    4586.07        4586.07   6888.440000
# 2            15.0                   w   15546.37       15546.37   9852.210000
# 3            21.0                   w   17260.40       17260.40  10118.930000
# 4            21.0                   w       0.00           0.00  16341.390792
# ...           ...                 ...        ...            ...           ...
# 421091       15.0                   f    1295.68        1295.68  10619.040000
# 421092       20.0                   w       0.00           0.00   5366.990000
# 421093       22.0                   w       0.00           0.00   6109.520000
# 421094       10.0                   f       0.00           0.00  23735.386335
# 421095        NaN                 NaN        NaN            NaN           NaN
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0              12239.77         10630.34        1609.43                 0.0
# 1               6888.44          5413.93        1474.51                 0.0
# 2               9852.21          5453.63        4398.58                 0.0
# 3              10118.93          6739.60        3379.33                 0.0
# 4              16341.39         14025.00        2316.39                 0.0
# ...                 ...              ...            ...                 ...
# 421091         10619.04          8704.32        1914.72                 0.0
# 421092          5366.99          1552.69        2234.98                 0.0
# 421093          6109.52          2527.70        2506.32                 0.0
# 421094         23735.39         20000.00        3735.39                 0.0
# 421095              NaN              NaN            NaN                 NaN
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0.00                   0.0000     Sep-2017           612.89
# 1             0.00                   0.0000     Sep-2017           329.67
# 2             0.00                   0.0000     Sep-2017           488.53
# 3             0.00                   0.0000     Sep-2017           507.58
# 4             0.00                   0.0000     Dec-2016         12764.01
# ...            ...                      ...          ...              ...
# 421091        0.00                   0.0000     Sep-2017           332.10
# 421092     1579.32                 284.2776     Jan-2016           317.86
# 421093     1075.50                 193.5900     May-2016           316.07
# 421094        0.00                   0.0000     May-2017          5776.74
# 421095         NaN                      NaN          NaN              NaN
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          Oct-2017           Sep-2017                         0.0
# 1          Oct-2017           Sep-2017                         0.0
# 2          Oct-2017           Sep-2017                         0.0
# 3          Oct-2017           Sep-2017                         0.0
# 4               NaN           Dec-2016                         0.0
# ...             ...                ...                         ...
# 421091     Oct-2017           Sep-2017                         0.0
# 421092          NaN           Oct-2016                         1.0
# 421093          NaN           Dec-2016                         0.0
# 421094          NaN           Jun-2017                         0.0
# 421095          NaN                NaN                         NaN
#
#         mths_since_last_major_derog  policy_code application_type  \
# 0                               NaN          1.0       INDIVIDUAL
# 1                               NaN          1.0       INDIVIDUAL
# 2                               NaN          1.0       INDIVIDUAL
# 3                              50.0          1.0       INDIVIDUAL
# 4                               NaN          1.0       INDIVIDUAL
# ...                             ...          ...              ...
# 421091                          NaN          1.0       INDIVIDUAL
# 421092                         22.0          1.0       INDIVIDUAL
# 421093                          NaN          1.0       INDIVIDUAL
# 421094                          NaN          1.0       INDIVIDUAL
# 421095                          NaN          NaN              NaN
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0                    NaN        NaN                       NaN             0.0
# 1                    NaN        NaN                       NaN             0.0
# 2                    NaN        NaN                       NaN             0.0
# 3                    NaN        NaN                       NaN             0.0
# 4                    NaN        NaN                       NaN             0.0
# ...                  ...        ...                       ...             ...
# 421091               NaN        NaN                       NaN             0.0
# 421092               NaN        NaN                       NaN             0.0
# 421093               NaN        NaN                       NaN             0.0
# 421094               NaN        NaN                       NaN             0.0
# 421095               NaN        NaN                       NaN             NaN
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 0                0.0     205155.0          1.0         3.0          1.0
# 1                0.0      23197.0          1.0         4.0          0.0
# 2                0.0     372407.0          1.0         1.0          1.0
# 3                0.0     127412.0          0.0         1.0          0.0
# 4                0.0      60381.0          1.0         0.0          0.0
# ...              ...          ...          ...         ...          ...
# 421091           0.0      25274.0          NaN         NaN          NaN
# 421092           0.0      58418.0          NaN         NaN          NaN
# 421093           0.0      34178.0          NaN         NaN          NaN
# 421094           0.0      33307.0          NaN         NaN          NaN
# 421095           NaN          NaN          NaN         NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0               4.0                 3.0       36812.0     79.0          1.0
# 1               0.0                28.0       15145.0     56.0          2.0
# 2               1.0                 5.0      352033.0      NaN          0.0
# 3               0.0                73.0        1456.0      4.0          0.0
# 4               0.0                91.0           0.0      NaN          2.0
# ...             ...                 ...           ...      ...          ...
# 421091          NaN                 NaN           NaN      NaN          NaN
# 421092          NaN                 NaN           NaN      NaN          NaN
# 421093          NaN                 NaN           NaN      NaN          NaN
# 421094          NaN                 NaN           NaN      NaN          NaN
# 421095          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0               1.0      2776.0      62.0           20400.0     1.0
# 1               6.0      2715.0      47.0           22600.0     0.0
# 2               0.0      9358.0      87.0           23300.0     1.0
# 3               1.0      3309.0       7.0           33600.0     1.0
# 4               5.0      4879.0      75.0           20900.0     0.0
# ...             ...         ...       ...               ...     ...
# 421091          NaN         NaN       NaN           17100.0     NaN
# 421092          NaN         NaN       NaN           27000.0     NaN
# 421093          NaN         NaN       NaN           18000.0     NaN
# 421094          NaN         NaN       NaN           41700.0     NaN
# 421095          NaN         NaN       NaN               NaN     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0               0.0           3.0                   5.0      25644.0
# 1               0.0           1.0                   6.0       1933.0
# 2               0.0           2.0                   1.0      74481.0
# 3               0.0           2.0                   1.0      14157.0
# 4               0.0           2.0                   5.0       5032.0
# ...             ...           ...                   ...          ...
# 421091          NaN           NaN                   2.0       3159.0
# 421092          NaN           NaN                   6.0       3895.0
# 421093          NaN           NaN                   7.0       3798.0
# 421094          NaN           NaN                   1.0       4163.0
# 421095          NaN           NaN                   NaN          NaN
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0               9924.0     21.9                       0.0          0.0
# 1              12925.0     37.9                       0.0          0.0
# 2               2926.0     87.4                       0.0          0.0
# 3              27172.0     10.9                       0.0          0.0
# 4                578.0     93.4                       0.0          0.0
# ...                ...      ...                       ...          ...
# 421091           448.0     95.1                       0.0          0.0
# 421092          3752.0     61.3                       0.0          0.0
# 421093          2554.0     75.9                       0.0          0.0
# 421094          8434.0     79.8                       0.0          0.0
# 421095             NaN      NaN                       NaN          NaN
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0                     87.0                 255.0                    8.0
# 1                     52.0                  76.0                    5.0
# 2                     76.0                 131.0                   85.0
# 3                    139.0                 398.0                   22.0
# 4                    138.0                 172.0                    2.0
# ...                    ...                   ...                    ...
# 421091               122.0                 115.0                   17.0
# 421092                56.0                  83.0                    5.0
# 421093               134.0                 108.0                    6.0
# 421094               146.0                 155.0                    5.0
# 421095                 NaN                   NaN                    NaN
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                  3.0       1.0                   8.0
# 1                  5.0       0.0                   5.0
# 2                  5.0       0.0                  85.0
# 3                 22.0       2.0                  22.0
# 4                  2.0       3.0                   2.0
# ...                ...       ...                   ...
# 421091            10.0       0.0                  90.0
# 421092             5.0       0.0                  12.0
# 421093             6.0       0.0                  17.0
# 421094             5.0       0.0                   5.0
# 421095             NaN       NaN                   NaN
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                            NaN                    3.0
# 1                            NaN                    2.0
# 2                            NaN                    0.0
# 3                            NaN                    0.0
# 4                            NaN                    2.0
# ...                          ...                    ...
# 421091                       NaN                    9.0
# 421092                       NaN                    0.0
# 421093                       NaN                   10.0
# 421094                       NaN                    0.0
# 421095                       NaN                    NaN
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                                  NaN                    0.0             1.0
# 1                                  NaN                    0.0             6.0
# 2                                  NaN                    0.0             3.0
# 3                                  NaN                    1.0             2.0
# 4                                  NaN                    0.0             3.0
# ...                                ...                    ...             ...
# 421091                             NaN                    0.0             3.0
# 421092                             NaN                    1.0             5.0
# 421093                             NaN                    0.0             4.0
# 421094                             NaN                    0.0             5.0
# 421095                             NaN                    NaN             NaN
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                   3.0          2.0        9.0        8.0            5.0
# 1                   7.0          6.0       10.0        4.0            8.0
# 2                   3.0          4.0        4.0       11.0            4.0
# 3                   3.0          4.0        6.0        6.0            7.0
# 4                  11.0          3.0        3.0        4.0           11.0
# ...                 ...          ...        ...        ...            ...
# 421091              6.0          3.0        4.0        7.0            7.0
# 421092              7.0          7.0        7.0        3.0           15.0
# 421093              6.0          4.0        4.0       12.0            7.0
# 421094              5.0          6.0        7.0        1.0            6.0
# 421095              NaN          NaN        NaN        NaN            NaN
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0                14.0                  3.0       9.0               0.0
# 1                16.0                  7.0      12.0               0.0
# 2                 4.0                  3.0       5.0               0.0
# 3                13.0                  3.0       9.0               0.0
# 4                13.0                 11.0      12.0               0.0
# ...               ...                  ...       ...               ...
# 421091            8.0                  6.0       9.0               0.0
# 421092           16.0                  7.0      17.0               0.0
# 421093           10.0                  6.0       9.0               0.0
# 421094            7.0                  5.0       8.0               0.0
# 421095            NaN                  NaN       NaN               NaN
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0                0.0                 0.0                 2.0            95.7
# 1                0.0                 0.0                 2.0           100.0
# 2                0.0                 0.0                 1.0           100.0
# 3                0.0                 0.0                 0.0            95.2
# 4                0.0                 0.0                 2.0           100.0
# ...              ...                 ...                 ...             ...
# 421091           0.0                 0.0                 1.0           100.0
# 421092           0.0                 1.0                 2.0            95.0
# 421093           0.0                 0.0                 3.0           100.0
# 421094           0.0                 0.0                 1.0           100.0
# 421095           NaN                 NaN                 NaN             NaN
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                    0.0                   0.0        0.0         247433.0
# 1                   33.3                   0.0        1.0          49732.0
# 2                   75.0                   0.0        0.0         370357.0
# 3                    0.0                   0.0        0.0         202351.0
# 4                   66.7                   0.0        0.0          72286.0
# ...                  ...                   ...        ...              ...
# 421091             100.0                   0.0        0.0          32950.0
# 421092              66.7                   0.0        0.0          96919.0
# 421093              50.0                   1.0        0.0          51239.0
# 421094              50.0                   0.0        1.0          43740.0
# 421095               NaN                   NaN        NaN              NaN
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                 41663.0         12700.0                     46367.0
# 1                 23197.0         20800.0                     27132.0
# 2                372407.0         23300.0                    347057.0
# 3                  4910.0         30500.0                     33631.0
# 4                 15646.0          8800.0                         0.0
# ...                   ...             ...                         ...
# 421091            25274.0          9200.0                     15850.0
# 421092            58418.0          9700.0                     69919.0
# 421093            34178.0         10600.0                     33239.0
# 421094            33307.0         41700.0                         0.0
# 421095                NaN             NaN                         NaN
#
#         revol_bal_joint  sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0                   NaN                       NaN                     NaN
# 1                   NaN                       NaN                     NaN
# 2                   NaN                       NaN                     NaN
# 3                   NaN                       NaN                     NaN
# 4                   NaN                       NaN                     NaN
# ...                 ...                       ...                     ...
# 421091              NaN                       NaN                     NaN
# 421092              NaN                       NaN                     NaN
# 421093              NaN                       NaN                     NaN
# 421094              NaN                       NaN                     NaN
# 421095              NaN                       NaN                     NaN
#
#         sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0                    NaN               NaN                 NaN
# 1                    NaN               NaN                 NaN
# 2                    NaN               NaN                 NaN
# 3                    NaN               NaN                 NaN
# 4                    NaN               NaN                 NaN
# ...                  ...               ...                 ...
# 421091               NaN               NaN                 NaN
# 421092               NaN               NaN                 NaN
# 421093               NaN               NaN                 NaN
# 421094               NaN               NaN                 NaN
# 421095               NaN               NaN                 NaN
#
#         sec_app_open_il_6m  sec_app_num_rev_accts  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 421091                 NaN                    NaN
# 421092                 NaN                    NaN
# 421093                 NaN                    NaN
# 421094                 NaN                    NaN
# 421095                 NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 421091                               NaN                                 NaN
# 421092                               NaN                                 NaN
# 421093                               NaN                                 NaN
# 421094                               NaN                                 NaN
# 421095                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                       NaN             N           NaN
# 1                                       NaN             N           NaN
# 2                                       NaN             N           NaN
# 3                                       NaN             N           NaN
# 4                                       NaN             N           NaN
# ...                                     ...           ...           ...
# 421091                                  NaN             N           NaN
# 421092                                  NaN             N           NaN
# 421093                                  NaN             N           NaN
# 421094                                  NaN             N           NaN
# 421095                                  NaN           NaN           NaN
#
#        hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0                  NaN             NaN            NaN              NaN
# 1                  NaN             NaN            NaN              NaN
# 2                  NaN             NaN            NaN              NaN
# 3                  NaN             NaN            NaN              NaN
# 4                  NaN             NaN            NaN              NaN
# ...                ...             ...            ...              ...
# 421091             NaN             NaN            NaN              NaN
# 421092             NaN             NaN            NaN              NaN
# 421093             NaN             NaN            NaN              NaN
# 421094             NaN             NaN            NaN              NaN
# 421095             NaN             NaN            NaN              NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                      NaN               NaN                     NaN
# 1                      NaN               NaN                     NaN
# 2                      NaN               NaN                     NaN
# 3                      NaN               NaN                     NaN
# 4                      NaN               NaN                     NaN
# ...                    ...               ...                     ...
# 421091                 NaN               NaN                     NaN
# 421092                 NaN               NaN                     NaN
# 421093                 NaN               NaN                     NaN
# 421094                 NaN               NaN                     NaN
# 421095                 NaN               NaN                     NaN
#
#         hardship_length  hardship_dpd hardship_loan_status  \
# 0                   NaN           NaN                  NaN
# 1                   NaN           NaN                  NaN
# 2                   NaN           NaN                  NaN
# 3                   NaN           NaN                  NaN
# 4                   NaN           NaN                  NaN
# ...                 ...           ...                  ...
# 421091              NaN           NaN                  NaN
# 421092              NaN           NaN                  NaN
# 421093              NaN           NaN                  NaN
# 421094              NaN           NaN                  NaN
# 421095              NaN           NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 421091                                         NaN
# 421092                                         NaN
# 421093                                         NaN
# 421094                                         NaN
# 421095                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# ...                                ...                           ...
# 421091                             NaN                           NaN
# 421092                             NaN                           NaN
# 421093                             NaN                           NaN
# 421094                             NaN                           NaN
# 421095                             NaN                           NaN
#
# [421096 rows x 137 columns]

# %%
raw_data.drop(raw_data.tail(1).index,inplace=True)

# %% [markdown]
# ## Type Conversion

# %%
# Intest Rate 
raw_data['int_rate'] = raw_data['int_rate'].str.rstrip('%').astype('float') / 100.0

# %% [markdown]
# ## Missing values statistics

# %%
mis_val = 100 * raw_data.isnull().sum() / len(raw_data)
mis_val_df = mis_val.sort_values(ascending=False).round(1)
mis_val_df.head(25)
# Out:
# revol_bal_joint                               100.0
# sec_app_revol_util                            100.0
# sec_app_num_rev_accts                         100.0
# sec_app_chargeoff_within_12_mths              100.0
# sec_app_collections_12_mths_ex_med            100.0
# sec_app_mths_since_last_major_derog           100.0
# sec_app_open_acc                              100.0
# sec_app_mort_acc                              100.0
# sec_app_inq_last_6mths                        100.0
# sec_app_earliest_cr_line                      100.0
# sec_app_open_il_6m                            100.0
# url                                           100.0
# member_id                                     100.0
# id                                            100.0
# desc                                          100.0
# dti_joint                                      99.9
# verification_status_joint                      99.9
# annual_inc_joint                               99.9
# orig_projected_additional_accrued_interest     99.7
# hardship_payoff_balance_amount                 99.7
# hardship_last_payment_amount                   99.7
# hardship_length                                99.7
# payment_plan_start_date                        99.7
# hardship_reason                                99.7
# hardship_status                                99.7
# dtype: float64

# %% [markdown]
# ## Data types

# %%
plt.figure(figsize=(8,4), dpi=100)
raw_data.dtypes.value_counts().sort_values().plot(kind='barh', color='b')
plt.title('Distributions of data types',fontsize=20)
plt.xlabel('Number of features',fontsize=15)
plt.ylabel('Data type',fontsize=15)
# Out:
# Text(0, 0.5, 'Data type')

# %%
categorical_features = raw_data.select_dtypes('object').apply(pd.Series.nunique, axis = 0).sort_values(ascending=False)
print(categorical_features)
droped_cat_feature = categorical_features.loc[categorical_features > 30].index.values
# Out:
# emp_title                    120812
# revol_util                     1211
# zip_code                        914
# earliest_cr_line                668
# addr_state                       49
# sub_grade                        35
# desc                             34
# last_credit_pull_d               34
# last_pymnt_d                     33
# title                            27
# purpose                          14
# issue_d                          12
# emp_length                       11
# hardship_reason                   9
# payment_plan_start_date           9
# hardship_end_date                 9
# hardship_start_date               8
# loan_status                       7
# grade                             7
# home_ownership                    4
# hardship_loan_status              4
# next_pymnt_d                      4
# verification_status               3
# hardship_status                   3
# pymnt_plan                        2
# initial_list_status               2
# application_type                  2
# hardship_flag                     2
# term                              2
# verification_status_joint         1
# hardship_type                     1
# id                                1
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Ich entferne alle Spalten mit mehr als 40% fehlenden Daten. Sie werden für die Modellierung und Exploration nicht benötigt.

# %%
reduced_dataset = raw_data.copy()
temp = [i for i in reduced_dataset.count() < 421097 * 0.6]
reduced_dataset.drop(reduced_dataset.columns[temp], axis=1, inplace=True)
reduced_dataset.shape
# Out:
# (421097, 85)

# %% [markdown]
# ## Categorical columns with too many unique values

# %%
categorical_features = reduced_dataset.select_dtypes('object').apply(pd.Series.nunique, axis = 0).sort_values(ascending=False)
droped_cat_feature = categorical_features.loc[categorical_features > 30].index.values
reduced_dataset.drop(droped_cat_feature, axis=1, inplace=True)
reduced_dataset.shape
# Out:
# (421097, 76)

# %% [markdown]
# ## Fill NaN values

# %% [markdown]
# ## Save reduced dataset

# %%
reduced_dataset.to_csv("./data/reduced_dataset.csv", sep=",", index=False)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Loan Status

# %%
plt.figure(figsize=(8,4), dpi=150)
f=sns.countplot(x="loan_status", data=reduced_dataset ,order = reduced_dataset['loan_status'].value_counts().index ,color='b')
f.set_xticklabels(f.get_xticklabels(),fontdict={'horizontalalignment':'right'},rotation=45)
f.set_xlabel("Status", fontsize=15)
f.set_ylabel("Amount", fontsize=15)
f.set_title("Loan Status Distribution", fontsize=20)
plt.show()

# %% [markdown]
# __Analyse__:

# %%
plt.figure(figsize=(8,4), dpi=150)
sns.boxplot(x="loan_amnt", y="loan_status", data=reduced_dataset)

# %% [markdown]
# __Analyse__:
# - Vollständig bezahlte Kredite sind in der Regel kleiner. Dies könnte auf das Alter der Darlehen zurückzuführen sein.
# - Die Ausfälle haben unter den anderen Darlehensstatus die höchste Anzahl.

# %% [markdown]
# ## Purpose

# %%
plt.figure(figsize=(8,4), dpi=150)
f = sns.countplot(x='purpose', data=reduced_dataset, order = reduced_dataset['purpose'].value_counts().index,color='b')
f.set_title("Purposes for Loan", fontsize=20)
f.set_xticklabels(f.get_xticklabels(),fontdict={'horizontalalignment':'right'},rotation=45)
f.set_xlabel("Purpose", fontsize=15)
f.set_ylabel('Amount', fontsize=15)
plt.show()

# %% [markdown]
# __Analyse__:

# %% [markdown]
# ## Interest Rate and Purpose

# %%
plt.figure(figsize=(8,4), dpi=150)
f = sns.boxplot(x='purpose', y='int_rate', data=reduced_dataset)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __Analyse__:
# - Kredite für Häuser, kleinere Unternehmungen und Investitionen für Erneuerbaren Energien haben durchschnittlich höhere Interest Rates

# %% [markdown]
# ## Interest Rate and Term

# %%
plt.figure(figsize=(8,4), dpi=150)
sns.boxplot(x='term', y='int_rate', data=reduced_dataset)
plt.show()

# %% [markdown]
# __Analyse__:
# - Kredite mit einer längeren Laufzeit haben durchschnittlich eine höhere Interest Rate.

# %% [markdown]
# ## Loan Status by Grade

# %%
cm = sns.light_palette("red", as_cmap=True)
round(pd.crosstab(reduced_dataset['loan_status'], reduced_dataset['grade'], normalize='columns')*100,2).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col0 {
#             background-color:  #ffd8d8;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col1 {
#             background-color:  #ffc7c7;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col2 {
#             background-color:  #ffabab;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col3 {
#             background-color:  #ff8383;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col4 {
#             background-color:  #ff5f5f;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col5 {
#             background-color:  #ff0a0a;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row0_col6 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col0 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col4 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col5 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row1_col6 {
#             background-color:  #ff4444;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row2_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col0 {
#             background-color:  #ff4646;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col1 {
#             background-color:  #ff5050;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col2 {
#             background-color:  #ff4d4d;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col3 {
#             background-color:  #ff4848;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col4 {
#             background-color:  #ff4545;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col5 {
#             background-color:  #ff2828;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row3_col6 {
#             background-color:  #ff2c2c;
#             color:  #f1f1f1;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col0 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col1 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col2 {
#             background-color:  #ffdfdf;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col3 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col4 {
#             background-color:  #ffdbdb;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col5 {
#             background-color:  #ffd9d9;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row4_col6 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col2 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col3 {
#             background-color:  #ffe3e3;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col4 {
#             background-color:  #ffe3e3;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col5 {
#             background-color:  #ffe2e2;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row5_col6 {
#             background-color:  #ffe2e2;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col0 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col1 {
#             background-color:  #ffe0e0;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col2 {
#             background-color:  #ffdddd;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col3 {
#             background-color:  #ffd9d9;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col4 {
#             background-color:  #ffd3d3;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col5 {
#             background-color:  #ffcece;
#             color:  #000000;
#         }    #T_45937876_3f9e_11ea_8028_8c8590432e48row6_col6 {
#             background-color:  #ffcdcd;
#             color:  #000000;
#         }</style><table id="T_45937876_3f9e_11ea_8028_8c8590432e48" ><thead>    <tr>        <th class="index_name level0" >grade</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >G</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45937876_3f9e_11ea_8028_8c8590432e48level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_45937876_3f9e_11ea_8028_8c8590432e48row0_col0" class="data row0 col0" >3.38</td>
#                         <td id="T_45937876_3f9e_11ea_8028_8c8590432e48row0_col1" class="data row0 col1" >7.38</td>
#                         <td id="T_45937876_3f9e_11ea_8028_8c8590432e48row0_col2" class="data row0 col2" >12.88</td>
#                         <td id="T_45937876_3f9e_11ea_8028_8c8590432e48row0_col3" class="data row0 col3" >19.16</td>
#                         <td id="T_45937

# %%
plt.figure(figsize=(6,6), dpi=100)
sns.boxplot(x='grade', y='int_rate', data=reduced_dataset, order = 'ABCDEFG')
plt.show()

# %% [markdown]
# __Analyse__:
# - Die von Lending Club vergebenen Bewertungen sind logisch. Niedriger eingestufte Darlehen werden erwartungsgemäß weniger wahrscheinlich bezahlt und haben höhere Interest Rates.

# %% [markdown]
# ## Loan Amount by Grade

# %%
plt.figure(figsize=(8,4), dpi=150)
def loan_binning(num):
    if num <= 10000:
        return '<=10000'
    elif num <= 20000:
        return '10000-20000'
    elif num <= 30000:
        return '20000-30000'
    else:
        return '>30000'
reduced_dataset['loan_bins'] = reduced_dataset['loan_amnt'].apply(loan_binning)
reduced_dataset.groupby(['grade','loan_bins']).size().unstack().plot(kind="bar", ax = plt.gca())
plt.ylabel("Number of loans")
# Out:
# Text(0, 0.5, 'Number of loans')

# %% [markdown]
# __Analyse__:
# -

# %% [markdown]
# ## Term by Grade

# %%
plt.figure(figsize=(8,4), dpi=150)
term_by_grade = reduced_dataset.groupby(['grade','term']).size().unstack().plot(kind="bar", ax = plt.gca())
plt.ylabel("Number of loans")
# Out:
# Text(0, 0.5, 'Number of loans')

# %% [markdown]
# __Analyse__:
# - Kredite mit schlechteren Bewertungen haben in der Regel eine längere Laufzeit.
